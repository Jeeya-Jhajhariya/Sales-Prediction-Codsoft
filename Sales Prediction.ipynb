# %%
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/anishjhajhariya/Downloads/advertising.csv',engine='python')
df.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
df.tail(10)
# Out:
#         TV  Radio  Newspaper  Sales
# 190   39.5   41.1        5.8   10.8
# 191   75.5   10.8        6.0   11.9
# 192   17.2    4.1       31.6    5.9
# 193  166.8   42.0        3.6   19.6
# 194  149.7   35.6        6.0   17.3
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.shape
# Out:
# (200, 4)

# %%
sns.scatterplot(x=df['TV'], y=df['Sales'], color='blue')
plt.show()

# %%
sns.scatterplot(x=df['Radio'], y=df['Sales'], color='red')
plt.show()

# %%
sns.scatterplot(x=df['Newspaper'], y=df['Sales'], color='green')
plt.show()

# %%
sns.lmplot(x='TV', y='Sales', data=df)
sns.lmplot(x='Radio', y='Sales', data=df)
sns.lmplot(x='Newspaper', y='Sales', data=df)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.hist(df['TV'], color='grey')
plt.title('TV')



plt.subplot(222)
plt.hist(df['Radio'], color='orange')
plt.title('Radio')



plt.subplot(223)
plt.hist(df['Newspaper'], color='magenta')
plt.title('Newspaper')



plt.subplot(224)
plt.hist(df['Sales'], color='cyan')
plt.title('Sales')

plt.show()

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='cividis')
plt.title('Correlation of Advertising mediums with Sales')
plt.show()

# %%
X = df[['TV']]
Y = df[['Sales']]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
#         TV
# 79   116.0
# 197  177.0
# 38    43.1
# 24    62.3
# 122  224.0
# ..     ...
# 106   25.0
# 14   204.1
# 92   217.7
# 179  165.6
# 102  280.2
#
# [160 rows x 1 columns]
#         TV
# 95   163.3
# 15   195.4
# 30   292.9
# 158   11.7
# 128  220.3
# 115   75.1
# 69   216.8
# 170   50.0
# 174  222.4
# 45   175.1
# 66    31.5
# 182   56.2
# 165  234.5
# 78     5.4
# 186  139.5
# 177  170.2
# 56     7.3
# 152  197.6
# 82    75.3
# 68   237.4
# 124  229.5
# 16    67.8
# 148   38.0
# 93   250.9
# 65    69.0
# 60    53.5
# 84   213.5
# 67   139.3
# 125   87.2
# 132    8.4
# 9    199.8
# 18    69.2
# 55   198.9
# 75    16.9
# 150  280.7
# 104  238.2
# 135   48.3
# 137  273.7
# 164  117.2
# 76    27.5
#      Sales
# 79    11.0
# 197   14.8
# 38    10.1
# 24     9.7
# 122   16.6
# ..     ...
# 106    7.2
# 14    19.0
# 92    19.4
# 179   17.6
# 102   19.8
#
# [160 rows x 1 columns]
#      Sales
# 95    16.9
# 15    22.4
# 30    21.4
# 158    7.3
# 128   24.7
# 115   12.6
# 69    22.3
# 170    8.4
# 174   16.5
# 45    16.1
# 66    11.0
# 182    8.7
# 165   16.9
# 78     5.3
# 186   10.3
# 177   16.7
# 56     5.5
# 152   16.6
# 82    11.3
# 68    18.9
# 124   19.7
# 16    12.5
# 148   10.9
# 93    22.2
# 65    11.3
# 60     8.1
# 84    21.7
# 67    13.4
# 125   10.6
# 132    5.7
# 9     15.6
# 18    11.3
# 55    23.7
# 75     8.7
# 150   16.1
# 104   20.7
# 135   11.6
# 137   20.8
# 164   11.9
# 76     6.9

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-cdeab5893867> in <module>
# ----> 1 plt.figure(figsize=(10, 8), facecolor='lightblue', edgecolor='green', alpha=0.5)
#       2 plt.scatter(Y_train, X_train_prediction)
#       3 plt.xlabel('Original Values')
#       4 plt.ylabel('Predicted Values')
#       5 plt.title('Original Values vs Predicted Values')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     685             dpi = 72
#     686
# --> 687         figManager = new_figure_manager(num, figsize=figsize,
#     688                                         dpi=dpi,
#     689                                         facecolor=facecolor,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     313     """Create a new figure manager instance."""
#     314     _warn_if_gui_out_of_main_thread()
# --> 315     return _backend_mod.new_figure_manager(*args, **kwargs)
#     316
#     317
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3491         from matplotlib.figure import Figure
#    3492         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3493         fig = fig_cls(*args, **kwargs)
#    3494         return cls.new_figure_manager_given_figure(num, fig)
#    3495
#
# TypeError: __init__() got an unexpected keyword argument 'alpha'
